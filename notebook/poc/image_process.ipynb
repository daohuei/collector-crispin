# %%
import os, sys

module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from collector_crispin.image_dumper import ImageFrame

image_frame = ImageFrame()

# %%
plt.figure(figsize=(15, 15))
plt.imshow(image_frame.black_frame)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(image_frame.white_frame)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(image_frame.sudden_motion_frame)

# %%
# Importing Image module from PIL package
from PIL import Image

Image.fromarray(image_frame.black_frame).save(f"{module_path}/data/black.jpg")
Image.fromarray(image_frame.white_frame).save(f"{module_path}/data/white.jpg")
Image.fromarray(image_frame.sudden_motion_frame).save(
    f"{module_path}/data/sudden_motion.jpg"
)

# %%
import os

path = ""
video_list = os.listdir(path)


def split_video_filename(filename: str):
    return {"jumbo_id": filename.split("_")[0], "filename": filename}


video_list = list(map(split_video_filename, video_list))
